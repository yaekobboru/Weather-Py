# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
#Create a new set of 2,000 random latitudes and longitudes.
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.

from citipy import citipy
# # Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

cities
# Out:
# ['floro',
#  'torbay',
#  'methoni',
#  'salamiyah',
#  'san rafael del sur',
#  'luderitz',
#  'jamestown',
#  'saint-joseph',
#  'bredasdorp',
#  'xuddur',
#  'illoqqortoormiut',
#  'ergolding',
#  'chicama',
#  'ushuaia',
#  'husavik',
#  'belushya guba',
#  'berlevag',
#  'waren',
#  'coquimbo',
#  'zhanatas',
#  'abnub',
#  'bathsheba',
#  'east london',
#  'saint-philippe',
#  'upernavik',
#  'arlit',
#  'mullaitivu',
#  'yining',
#  'ilulissat',
#  'mahebourg',
#  'portree',
#  'ribeira grande',
#  'buchanan',
#  'iquique',
#  'rio grande',
#  'maues',
#  'rondonopolis',
#  'jalu',
#  'kijabe',
#  'oktyabrskiy',
#  'manaure',
#  'kud',
#  'port alfred',
#  'ndioum',
#  'axim',
#  'san pedro',
#  'kavaratti',
#  'dikson',
#  'killybegs',
#  'barentsburg',
#  'grand river south east',
#  'nikki',
#  'roseau',
#  'ponta do sol',
#  'sistranda',
#  'bonavista',
#  'saint anthony',
#  'attawapiskat',
#  'san-pedro',
#  'santa lucia',
#  'tambul',
#  'qaanaaq',
#  'saveh',
#  'forssa',
#  'busselton',
#  'nizwa',
#  'dingle',
#  'taolanaro',
#  'belmonte',
#  'saint-augustin',
#  'kaputa',
#  'bambous virieux',
#  'lagoa',
#  'mendi',
#  'saint-louis',
#  'tasiilaq',
#  'cape town',
#  'garhi khairo',
#  'kathmandu',
#  'san alberto',
#  'quatre cocos',
#  'tabou',
#  'laguna',
#  'georgetown',
#  'chodavaram',
#  'hermanus',
#  'astana',
#  'manta',
#  'khandbari',
#  'uzventis',
#  'narsaq',
#  'punta arenas',
#  'jardim',
#  'macherla',
#  'matay',
#  'andros town',
#  'calella',
#  'bud',
#  'harper',
#  'havre-saint-pierre',
#  'sindor',
#  'puchezh',
#  'chuy',
#  'marcona',
#  'iqaluit',
#  'fort-shevchenko',
#  'cockburn town',
#  'tsihombe',
#  'pyshchug',
#  'adrar',
#  'bathurst',
#  'dindori',
#  'arraial do cabo',
#  'nador',
#  'longyearbyen',
#  'taoudenni',
#  'bhawanipatna',
#  'ambovombe',
#  'kutum',
#  'katsiveli',
#  'mazamari',
#  'bur gabo',
#  'comodoro rivadavia',
#  'tornio',
#  'cidreira',
#  'borovskoy',
#  'mar del plata',
#  'kodinar',
#  'tocopilla',
#  'hunza',
#  'victoria',
#  'chirongui',
#  'sol-iletsk',
#  'sao miguel',
#  'amderma',
#  'amanganj',
#  'oranjemund',
#  'nantucket',
#  'laela',
#  'sao miguel do araguaia',
#  'oberndorf',
#  'bengkulu',
#  'zelenokumsk',
#  'yar-sale',
#  'synya',
#  'hithadhoo',
#  'tall kayf',
#  'teya',
#  'madras',
#  'severnyy',
#  'mount darwin',
#  'mahajanga',
#  'kudahuvadhoo',
#  'dakoro',
#  'babanusah',
#  'sao filipe',
#  'luangwa',
#  'longlac',
#  'lieksa',
#  'itaberai',
#  'souillac',
#  'kruisfontein',
#  'kamenka',
#  'eydhafushi',
#  'zalegoshch',
#  'ostrovnoy',
#  'micheweni',
#  'la ligua',
#  'werda',
#  'uray',
#  'hofn',
#  'straumen',
#  'verkhnyaya inta',
#  'safita',
#  'itarema',
#  'saint george',
#  'praia',
#  'vardo',
#  'los llanos de aridane',
#  'guatire',
#  'rayachoti',
#  'andros',
#  'sao felix do xingu',
#  'the valley',
#  'araxa',
#  'san borja',
#  'mattru',
#  'laguna de perlas',
#  'finote selam',
#  'charagua',
#  'inta',
#  'padang',
#  'yazman',
#  'paldiski',
#  'necochea',
#  'kuche',
#  'drabiv',
#  'suda',
#  'alta floresta',
#  'kiomboi',
#  'kasongo-lunda',
#  'san carlos de bariloche',
#  'maralal',
#  'huicungo',
#  'nicoya',
#  'san andres',
#  'chapais',
#  'gagnoa',
#  'umzimvubu',
#  'buraydah',
#  'hambantota',
#  'turayf',
#  'salinopolis',
#  'henties bay',
#  'viedma',
#  'lucapa',
#  'lagos',
#  'kajaani',
#  'eenhana',
#  'bafq',
#  'porto novo',
#  'ebolowa',
#  'san juan',
#  'maloshuyka',
#  'puerto madryn',
#  'lyubech',
#  'bandarbeyla',
#  'brighton',
#  'louisbourg',
#  'cascais',
#  'pokhara',
#  'marawi',
#  'djambala',
#  'paamiut',
#  'hammerfest',
#  'kempen',
#  'alexandria',
#  'tumannyy',
#  'faya',
#  'klaksvik',
#  'nuqui',
#  'tessalit',
#  'port elizabeth',
#  'bereda',
#  'narasannapeta',
#  'turukhansk',
#  'port-cartier',
#  'bonthe',
#  'kibre mengist',
#  'leh',
#  'baneh',
#  'barbar',
#  'raga',
#  'natal',
#  'ayagoz',
#  'abu dhabi',
#  'sur',
#  'yauya',
#  'calabozo',
#  'ilinge',
#  'santa maria',
#  'iquitos',
#  'samana',
#  'biltine',
#  'el tigre',
#  'trairi',
#  'sheboygan',
#  'sukhumi',
#  'awjilah',
#  'lubao',
#  'el balyana',
#  'benguela',
#  'iralaya',
#  'olafsvik',
#  'kabinda',
#  'jumla',
#  'mansa',
#  'tatawin',
#  'kreminna',
#  'vila franca do campo',
#  'palaikastron',
#  'springdale',
#  'nuuk',
#  'villacarrillo',
#  'jacmel',
#  'mariinsk',
#  'quartucciu',
#  'gat',
#  'nara',
#  'okahandja',
#  'somers point',
#  'sao joao da barra',
#  'lebu',
#  'arona',
#  'blonduos',
#  'campobello di mazara',
#  'gradsko',
#  'saldanha',
#  'talcahuano',
#  'coihaique',
#  'boa vista',
#  'ladario',
#  'atar',
#  'karpogory',
#  'bad urach',
#  'eyl',
#  'mabaruma',
#  'sydney mines',
#  'grand haven',
#  'vila velha',
#  'pontes e lacerda',
#  'caibarien',
#  'cap malheureux',
#  'qaqortoq',
#  'garowe',
#  'veinticinco de mayo',
#  'codrington',
#  'nanortalik',
#  'villa vazquez',
#  'ancud',
#  'johnstown',
#  'terek',
#  'luau',
#  'florianopolis',
#  'miranda',
#  'dombarovskiy',
#  'bridgetown',
#  'tafresh',
#  'itajuba',
#  'leeuwarden',
#  'zory',
#  'loandjili',
#  'buta',
#  'chongwe',
#  'pangody',
#  'blyth',
#  'hakkari',
#  'burica',
#  'nakuru',
#  'cayenne',
#  'sorland',
#  'oksovskiy',
#  'lokosovo',
#  'jiroft',
#  'cangucu',
#  'skorodnoye',
#  'swellendam',
#  'lokoja',
#  'mosquera',
#  'kusadak',
#  'bosaso',
#  'la palma',
#  'itaituba',
#  'hargeysa',
#  'borujerd',
#  'grande-riviere',
#  'bulungu',
#  'khorramshahr',
#  'maniitsoq',
#  'middleton',
#  'yala',
#  'fillira',
#  'samfya',
#  'kuytun',
#  'cabedelo',
#  'mangotsfield',
#  'tuggurt',
#  'verkhniy baskunchak',
#  'dolbeau',
#  'banapur',
#  'gornopravdinsk',
#  'khash',
#  'dembi dolo',
#  'juba',
#  'thinadhoo',
#  'upata',
#  'dadu',
#  'namibe',
#  'macusani',
#  'kopavogur',
#  'saint-pierre',
#  'paratebueno',
#  'le port',
#  'vestmanna',
#  'talavera de la reina',
#  'conceicao do araguaia',
#  'abeche',
#  'asfi',
#  'aspindza',
#  'sinnamary',
#  'tubruq',
#  'riyadh',
#  'chimbote',
#  'nkoteng',
#  'rapar',
#  'palmas bellas',
#  'cururupu',
#  'touros',
#  'rawson',
#  'pazaric',
#  'san cristobal',
#  'vestmannaeyjar',
#  'nadym',
#  'mudigere',
#  'salalah',
#  'talnakh',
#  'verkhnyaya maksakovka',
#  'jijiga',
#  'svencionys',
#  'vuktyl',
#  'melfi',
#  'novyy urengoy',
#  'korla',
#  'corinto',
#  'tasbuget',
#  'kaabong',
#  'potiskum',
#  'muros',
#  'road town',
#  'dutse',
#  'dakar',
#  'socota',
#  'jacareacanga',
#  'kirishi',
#  'gbarnga',
#  'de aar',
#  'camacha',
#  'sao borja',
#  'dharchula',
#  'margate',
#  'kalachinsk',
#  'mazagao',
#  'kayerkan',
#  'pisco',
#  'maceio',
#  'signagi',
#  'jalalpur',
#  'hit',
#  'onega',
#  'morant bay',
#  'bani',
#  'alamor',
#  'darlowo',
#  'talah',
#  'mehamn',
#  'togur',
#  'nioro',
#  'mbandaka',
#  'dudinka',
#  'howick',
#  'la chapelle-sur-erdre',
#  'gambela',
#  'clyde river',
#  'puerto narino',
#  'martinez',
#  'port hawkesbury',
#  'thompson',
#  'westpunt',
#  'caceres',
#  'urucara',
#  'stornoway',
#  'forasti',
#  'karaton',
#  'machiques',
#  'qasigiannguit',
#  'tabuk',
#  'emba',
#  'sahrak',
#  'pilao arcado',
#  'caravelas',
#  'belene',
#  'oussouye',
#  'youghal',
#  'kemin',
#  'witu',
#  'bogorodskoye',
#  'brigantine',
#  'westport',
#  'chiojdu',
#  'carora',
#  'kroderen',
#  'akureyri',
#  'doha',
#  'kentau',
#  'kidal',
#  'oshnaviyeh',
#  'marystown',
#  'copiapo',
#  'taltal',
#  'vangaindrano',
#  'jinka',
#  'skibbereen',
#  'kaduqli',
#  'imbituba',
#  'ambam',
#  'duz',
#  'kannad',
#  'basqal',
#  'shieli',
#  'sakakah',
#  'lauchhammer',
#  'caiaponia',
#  'jutai',
#  'castro',
#  'inhambane',
#  'belyy yar',
#  'ejea de los caballeros',
#  'kuraymah',
#  'buldana',
#  'kaniama',
#  'mogadishu',
#  'banda aceh',
#  'beira',
#  'port-gentil',
#  'hamilton',
#  'pangnirtung',
#  'kurtamysh',
#  'takoradi',
#  'rodnykove',
#  'manyana',
#  'binga',
#  'ust-ishim',
#  'teguldet',
#  'gweta',
#  'soyo',
#  'coruripe',
#  'richards bay',
#  'pritzwalk',
#  'masindi',
#  'mosjoen',
#  'porto velho',
#  'skelleftea',
#  'jadu',
#  'benghazi',
#  'volchikha',
#  'homa bay',
#  'khormuj',
#  'katiola',
#  'harqalah',
#  'isla mujeres',
#  'shache',
#  'sault sainte marie',
#  'grand-lahou',
#  'antalaha',
#  'rio gallegos',
#  'grand gaube',
#  'robertsport',
#  'karaul',
#  'cap-aux-meules',
#  'rantoul',
#  'waddan',
#  'kavant',
#  'kirovskiy',
#  'halvad',
#  'santa rosa',
#  'szczytno',
#  'lonevag',
#  'boden',
#  'nova serrana',
#  'bongandanga',
#  'anloga',
#  'paita',
#  'kiknur',
#  'placido de castro',
#  'ponta delgada',
#  'sisimiut',
#  'lodja',
#  'matara',
#  'lima',
#  'tawkar',
#  'octeville',
#  'chany',
#  'mormugao',
#  'mbacke',
#  'oxford',
#  'ciudad bolivar',
#  'nigde',
#  'pajan',
#  'pimenta bueno',
#  'bardiyah',
#  'beri',
#  'aqtobe',
#  'sao raimundo nonato',
#  'puerto leguizamo',
#  'skalistyy',
#  'tazovskiy',
#  'gopalganj',
#  'constitucion',
#  'baherden',
#  'gualaquiza',
#  'amos',
#  'luanda',
#  'larsnes',
#  'danilovka',
#  'betioky',
#  'kulynychi',
#  'theunissen',
#  'dabat',
#  'santiago del estero',
#  'puerto lempira',
#  'beloha',
#  'soavinandriana',
#  'abonnema',
#  'moen',
#  'maldonado',
#  'przhevalskoye',
#  'skegness',
#  'elat',
#  'mercedes',
#  'puerto baquerizo moreno',
#  'roald',
#  'umm jarr',
#  'meulaboh',
#  'paradwip',
#  'ust-kulom',
#  'abha',
#  'blagoyevo',
#  'puerto colombia',
#  'zholymbet',
#  'wajir',
#  'mazabuka',
#  'bubaque',
#  'morgantown',
#  'rocha',
#  'mutsamudu',
#  'angoche',
#  'cefalu',
#  'maputo',
#  'lvov',
#  'brae',
#  'nefteyugansk',
#  'guider',
#  'camocim',
#  'galgani',
#  'safwah',
#  'mrirt',
#  'iskilip',
#  'maarianhamina',
#  'aksu',
#  'kambove',
#  'sile',
#  'rockland',
#  'iskateley',
#  'goderich',
#  'aswan',
#  'monrovia',
#  'bridgwater',
#  'nueva loja',
#  'patti',
#  'hobyo',
#  'ottobrunn',
#  'gataia',
#  'alta',
#  'tarudant',
#  'esna',
#  'manali',
#  'galle',
#  'montepuez',
#  'lar',
#  'usinsk',
#  'sidi bu zayd',
#  'pombia',
#  'maraa',
#  'ilebo',
#  'malanje',
#  'ambilobe',
#  'mitu',
#  'coulihaut',
#  'tshane',
#  'perigueux',
#  'sabana de torres',
#  'geraldton',
#  'dera ghazi khan',
#  'taywarah',
#  'napasar',
#  'panama city',
#  'grootfontein',
#  'gurgan',
#  'ankazoabo',
#  'berbera',
#  'santa marta',
#  'kijini',
#  'odweyne',
#  'karanpura',
#  'sarai naurang',
#  'challapata',
#  'north myrtle beach',
#  'campoverde',
#  'carnarvon',
#  'rabak',
#  'grindavik',
#  'sinnar',
#  'plouzane',
#  'kalmunai',
#  'camabatela',
#  'sept-iles',
#  'matthews',
#  'paros',
#  'oum hadjer',
#  'alakurtti',
#  'itamaraju',
#  'nikel',
#  'sembe',
#  'andenes',
#  'acarau',
#  'mao',
#  'rio branco',
#  'yenagoa',
#  'mananjary',
#  'mecca',
#  'dhidhdhoo',
#  'awbari',
#  'koygorodok',
#  'were ilu',
#  'zemio',
#  'aguimes',
#  'bolzano',
#  'evansville',
#  'el cobre',
#  'plettenberg bay',
#  'prainha',
#  'gwembe',
#  'obera',
#  'umea',
#  'rauma',
#  'harrisburg',
#  'cruz alta',
#  'dmitriyevka',
#  'najran',
#  'libertador general san martin',
#  'semme',
#  'gorshechnoye',
#  'disna',
#  'urdzhar',
#  'chik',
#  'mantua',
#  'alfenas',
#  'siuna',
#  'warmbad',
#  'lokken verk',
#  'prilep',
#  'taggia',
#  'varhaug',
#  'pyaozerskiy',
#  'skagastrond',
#  'pachino',
#  'panaba',
#  'krasnogvardeyskiy',
#  'gurupi',
#  'ambodifototra',
#  'veraval',
#  'banposh',
#  'state college',
#  'kabalo',
#  'keti bandar',
#  'nahavand',
#  'decatur',
#  'lubaczow',
#  'znamenka',
#  'japura',
#  'korem',
#  'yendi',
#  'havoysund',
#  'lennoxtown',
#  'carutapera',
#  'tayga',
#  'kharp',
#  'valparaiso',
#  'bolungarvik']

# %%
#Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Perform an API call with the OpenWeatherMap.
# Initialize counters
city_data = []
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        record_count = 1
        set_count += 1
        #record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_name = city_weather["name"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : current_description
                        #  "Date": city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | floro
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | methoni
# Processing Record 4 of Set 1 | salamiyah
# Processing Record 5 of Set 1 | san rafael del sur
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | saint-joseph
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | xuddur
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | ergolding
# Processing Record 13 of Set 1 | chicama
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | husavik
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | berlevag
# Processing Record 18 of Set 1 | waren
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 1 | abnub
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | arlit
# Processing Record 27 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 1 | yining
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | portree
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | buchanan
# Processing Record 34 of Set 1 | iquique
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | maues
# Processing Record 37 of Set 1 | rondonopolis
# Processing Record 38 of Set 1 | jalu
# Processing Record 39 of Set 1 | kijabe
# Processing Record 40 of Set 1 | oktyabrskiy
# Processing Record 41 of Set 1 | manaure
# Processing Record 42 of Set 1 | kud
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | ndioum
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | san pedro
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | killybegs
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | nikki
# Processing Record 3 of Set 2 | roseau
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | sistranda
# Processing Record 6 of Set 2 | bonavista
# Processing Record 7 of Set 2 | saint anthony
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | san-pedro
# Processing Record 10 of Set 2 | santa lucia
# Processing Record 11 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | saveh
# Processing Record 14 of Set 2 | forssa
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | nizwa
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | belmonte
# Processing Record 20 of Set 2 | saint-augustin
# Processing Record 21 of Set 2 | kaputa
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | mendi
# Processing Record 25 of Set 2 | saint-louis
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | garhi khairo
# Processing Record 29 of Set 2 | kathmandu
# Processing Record 30 of Set 2 | san alberto
# Processing Record 31 of Set 2 | quatre cocos
# Processing Record 32 of Set 2 | tabou
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | chodavaram
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | astana
# Processing Record 38 of Set 2 | manta
# Processing Record 39 of Set 2 | khandbari
# Processing Record 40 of Set 2 | uzventis
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | jardim
# Processing Record 44 of Set 2 | macherla
# Processing Record 45 of Set 2 | matay
# Processing Record 46 of Set 2 | andros town
# Processing Record 47 of Set 2 | calella
# Processing Record 48 of Set 2 | bud
# Processing Record 49 of Set 2 | harper
# Processing Record 50 of Set 2 | havre-saint-pierre
# Processing Record 1 of Set 3 | sindor
# Processing Record 2 of Set 3 | puchezh
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | fort-shevchenko
# Processing Record 7 of Set 3 | cockburn town
# Processing Record 8 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 3 | pyshchug
# Processing Record 10 of Set 3 | adrar
# Processing Record 11 of Set 3 | bathurst
# Processing Record 12 of Set 3 | dindori
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | nador
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | taoudenni
# Processing Record 17 of Set 3 | bhawanipatna
# Processing Record 18 of Set 3 | ambovombe
# Processing Record 19 of Set 3 | kutum
# Processing Record 20 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 3 | mazamari
# Processing Record 22 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 3 | comodoro rivadavia
# Processing Record 24 of Set 3 | tornio
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | borovskoy
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | kodinar
# Processing Record 29 of Set 3 | tocopilla
# Processing Record 30 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | chirongui
# Processing Record 33 of Set 3 | sol-iletsk
# Processing Record 34 of Set 3 | sao miguel
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | amanganj
# Processing Record 37 of Set 3 | oranjemund
# Processing Record 38 of Set 3 | nantucket
# Processing Record 39 of Set 3 | laela
# Processing Record 40 of Set 3 | sao miguel do araguaia
# Processing Record 41 of Set 3 | oberndorf
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | zelenokumsk
# Processing Record 44 of Set 3 | yar-sale
# Processing Record 45 of Set 3 | synya
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | tall kayf
# Processing Record 48 of Set 3 | teya
# Processing Record 49 of Set 3 | madras
# Processing Record 50 of Set 3 | severnyy
# Processing Record 1 of Set 4 | mount darwin
# Processing Record 2 of Set 4 | mahajanga
# Processing Record 3 of Set 4 | kudahuvadhoo
# Processing Record 4 of Set 4 | dakoro
# Processing Record 5 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | luangwa
# Processing Record 8 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 4 | lieksa
# Processing Record 10 of Set 4 | itaberai
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | kamenka
# Processing Record 14 of Set 4 | eydhafushi
# Processing Record 15 of Set 4 | zalegoshch
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | micheweni
# Processing Record 18 of Set 4 | la ligua
# Processing Record 19 of Set 4 | werda
# Processing Record 20 of Set 4 | uray
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | straumen
# Processing Record 23 of Set 4 | verkhnyaya inta
# Processing Record 24 of Set 4 | safita
# Processing Record 25 of Set 4 | itarema
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | praia
# Processing Record 28 of Set 4 | vardo
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | guatire
# Processing Record 31 of Set 4 | rayachoti
# Processing Record 32 of Set 4 | andros
# Processing Record 33 of Set 4 | sao felix do xingu
# Processing Record 34 of Set 4 | the valley
# Processing Record 35 of Set 4 | araxa
# Processing Record 36 of Set 4 | san borja
# Processing Record 37 of Set 4 | mattru
# Processing Record 38 of Set 4 | laguna de perlas
# Processing Record 39 of Set 4 | finote selam
# Processing Record 40 of Set 4 | charagua
# Processing Record 41 of Set 4 | inta
# Processing Record 42 of Set 4 | padang
# Processing Record 43 of Set 4 | yazman
# Processing Record 44 of Set 4 | paldiski
# Processing Record 45 of Set 4 | necochea
# Processing Record 46 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 4 | drabiv
# Processing Record 48 of Set 4 | suda
# Processing Record 49 of Set 4 | alta floresta
# Processing Record 50 of Set 4 | kiomboi
# Processing Record 1 of Set 5 | kasongo-lunda
# Processing Record 2 of Set 5 | san carlos de bariloche
# Processing Record 3 of Set 5 | maralal
# Processing Record 4 of Set 5 | huicungo
# Processing Record 5 of Set 5 | nicoya
# Processing Record 6 of Set 5 | san andres
# Processing Record 7 of Set 5 | chapais
# Processing Record 8 of Set 5 | gagnoa
# Processing Record 9 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 5 | buraydah
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | turayf
# Processing Record 13 of Set 5 | salinopolis
# Processing Record 14 of Set 5 | henties bay
# Processing Record 15 of Set 5 | viedma
# Processing Record 16 of Set 5 | lucapa
# Processing Record 17 of Set 5 | lagos
# Processing Record 18 of Set 5 | kajaani
# Processing Record 19 of Set 5 | eenhana
# Processing Record 20 of Set 5 | bafq
# Processing Record 21 of Set 5 | porto novo
# Processing Record 22 of Set 5 | ebolowa
# Processing Record 23 of Set 5 | san juan
# Processing Record 24 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 5 | puerto madryn
# Processing Record 26 of Set 5 | lyubech
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | brighton
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | cascais
# Processing Record 31 of Set 5 | pokhara
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | djambala
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | hammerfest
# Processing Record 36 of Set 5 | kempen
# Processing Record 37 of Set 5 | alexandria
# Processing Record 38 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | nuqui
# Processing Record 42 of Set 5 | tessalit
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | bereda
# Processing Record 45 of Set 5 | narasannapeta
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | port-cartier
# Processing Record 48 of Set 5 | bonthe
# Processing Record 49 of Set 5 | kibre mengist
# Processing Record 50 of Set 5 | leh
# Processing Record 1 of Set 6 | baneh
# Processing Record 2 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 6 | raga
# Processing Record 4 of Set 6 | natal
# Processing Record 5 of Set 6 | ayagoz
# Processing Record 6 of Set 6 | abu dhabi
# Processing Record 7 of Set 6 | sur
# Processing Record 8 of Set 6 | yauya
# Processing Record 9 of Set 6 | calabozo
# Processing Record 10 of Set 6 | ilinge
# Processing Record 11 of Set 6 | santa maria
# Processing Record 12 of Set 6 | iquitos
# Processing Record 13 of Set 6 | samana
# Processing Record 14 of Set 6 | biltine
# Processing Record 15 of Set 6 | el tigre
# Processing Record 16 of Set 6 | trairi
# Processing Record 17 of Set 6 | sheboygan
# Processing Record 18 of Set 6 | sukhumi
# Processing Record 19 of Set 6 | awjilah
# Processing Record 20 of Set 6 | lubao
# Processing Record 21 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 6 | benguela
# Processing Record 23 of Set 6 | iralaya
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | kabinda
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | mansa
# Processing Record 28 of Set 6 | tatawin
# Processing Record 29 of Set 6 | kreminna
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | palaikastron
# Processing Record 32 of Set 6 | springdale
# Processing Record 33 of Set 6 | nuuk
# Processing Record 34 of Set 6 | villacarrillo
# Processing Record 35 of Set 6 | jacmel
# Processing Record 36 of Set 6 | mariinsk
# Processing Record 37 of Set 6 | quartucciu
# Processing Record 38 of Set 6 | gat
# Processing Record 39 of Set 6 | nara
# Processing Record 40 of Set 6 | okahandja
# Processing Record 41 of Set 6 | somers point
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | arona
# Processing Record 45 of Set 6 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 6 | campobello di mazara
# Processing Record 47 of Set 6 | gradsko
# Processing Record 48 of Set 6 | saldanha
# Processing Record 49 of Set 6 | talcahuano
# Processing Record 50 of Set 6 | coihaique
# Processing Record 1 of Set 7 | boa vista
# Processing Record 2 of Set 7 | ladario
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | karpogory
# Processing Record 5 of Set 7 | bad urach
# Processing Record 6 of Set 7 | eyl
# Processing Record 7 of Set 7 | mabaruma
# Processing Record 8 of Set 7 | sydney mines
# Processing Record 9 of Set 7 | grand haven
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | pontes e lacerda
# Processing Record 12 of Set 7 | caibarien
# Processing Record 13 of Set 7 | cap malheureux
# Processing Record 14 of Set 7 | qaqortoq
# Processing Record 15 of Set 7 | garowe
# Processing Record 16 of Set 7 | veinticinco de mayo
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | villa vazquez
# City not found. Skipping...
# Processing Record 20 of Set 7 | ancud
# Processing Record 21 of Set 7 | johnstown
# Processing Record 22 of Set 7 | terek
# Processing Record 23 of Set 7 | luau
# Processing Record 24 of Set 7 | florianopolis
# Processing Record 25 of Set 7 | miranda
# Processing Record 26 of Set 7 | dombarovskiy
# Processing Record 27 of Set 7 | bridgetown
# Processing Record 28 of Set 7 | tafresh
# Processing Record 29 of Set 7 | itajuba
# Processing Record 30 of Set 7 | leeuwarden
# Processing Record 31 of Set 7 | zory
# Processing Record 32 of Set 7 | loandjili
# Processing Record 33 of Set 7 | buta
# Processing Record 34 of Set 7 | chongwe
# Processing Record 35 of Set 7 | pangody
# Processing Record 36 of Set 7 | blyth
# Processing Record 37 of Set 7 | hakkari
# Processing Record 38 of Set 7 | burica
# City not found. Skipping...
# Processing Record 39 of Set 7 | nakuru
# Processing Record 40 of Set 7 | cayenne
# Processing Record 41 of Set 7 | sorland
# Processing Record 42 of Set 7 | oksovskiy
# Processing Record 43 of Set 7 | lokosovo
# Processing Record 44 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 7 | cangucu
# Processing Record 46 of Set 7 | skorodnoye
# Processing Record 47 of Set 7 | swellendam
# Processing Record 48 of Set 7 | lokoja
# Processing Record 49 of Set 7 | mosquera
# Processing Record 50 of Set 7 | kusadak
# Processing Record 1 of Set 8 | bosaso
# Processing Record 2 of Set 8 | la palma
# Processing Record 3 of Set 8 | itaituba
# Processing Record 4 of Set 8 | hargeysa
# Processing Record 5 of Set 8 | borujerd
# Processing Record 6 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 7 of Set 8 | bulungu
# Processing Record 8 of Set 8 | khorramshahr
# Processing Record 9 of Set 8 | maniitsoq
# Processing Record 10 of Set 8 | middleton
# Processing Record 11 of Set 8 | yala
# Processing Record 12 of Set 8 | fillira
# City not found. Skipping...
# Processing Record 13 of Set 8 | samfya
# Processing Record 14 of Set 8 | kuytun
# Processing Record 15 of Set 8 | cabedelo
# Processing Record 16 of Set 8 | mangotsfield
# Processing Record 17 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 8 | verkhniy baskunchak
# Processing Record 19 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 8 | banapur
# Processing Record 21 of Set 8 | gornopravdinsk
# Processing Record 22 of Set 8 | khash
# Processing Record 23 of Set 8 | dembi dolo
# Processing Record 24 of Set 8 | juba
# Processing Record 25 of Set 8 | thinadhoo
# Processing Record 26 of Set 8 | upata
# Processing Record 27 of Set 8 | dadu
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | macusani
# Processing Record 30 of Set 8 | kopavogur
# Processing Record 31 of Set 8 | saint-pierre
# Processing Record 32 of Set 8 | paratebueno
# Processing Record 33 of Set 8 | le port
# Processing Record 34 of Set 8 | vestmanna
# Processing Record 35 of Set 8 | talavera de la reina
# Processing Record 36 of Set 8 | conceicao do araguaia
# Processing Record 37 of Set 8 | abeche
# Processing Record 38 of Set 8 | asfi
# Processing Record 39 of Set 8 | aspindza
# Processing Record 40 of Set 8 | sinnamary
# Processing Record 41 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 8 | riyadh
# Processing Record 43 of Set 8 | chimbote
# Processing Record 44 of Set 8 | nkoteng
# Processing Record 45 of Set 8 | rapar
# Processing Record 46 of Set 8 | palmas bellas
# Processing Record 47 of Set 8 | cururupu
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | rawson
# Processing Record 50 of Set 8 | pazaric
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | vestmannaeyjar
# Processing Record 3 of Set 9 | nadym
# Processing Record 4 of Set 9 | mudigere
# Processing Record 5 of Set 9 | salalah
# Processing Record 6 of Set 9 | talnakh
# Processing Record 7 of Set 9 | verkhnyaya maksakovka
# Processing Record 8 of Set 9 | jijiga
# Processing Record 9 of Set 9 | svencionys
# Processing Record 10 of Set 9 | vuktyl
# Processing Record 11 of Set 9 | melfi
# Processing Record 12 of Set 9 | novyy urengoy
# Processing Record 13 of Set 9 | korla
# Processing Record 14 of Set 9 | corinto
# Processing Record 15 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 9 | kaabong
# Processing Record 17 of Set 9 | potiskum
# Processing Record 18 of Set 9 | muros
# Processing Record 19 of Set 9 | road town
# Processing Record 20 of Set 9 | dutse
# Processing Record 21 of Set 9 | dakar
# Processing Record 22 of Set 9 | socota
# Processing Record 23 of Set 9 | jacareacanga
# Processing Record 24 of Set 9 | kirishi
# Processing Record 25 of Set 9 | gbarnga
# Processing Record 26 of Set 9 | de aar
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | sao borja
# Processing Record 29 of Set 9 | dharchula
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | kalachinsk
# Processing Record 32 of Set 9 | mazagao
# Processing Record 33 of Set 9 | kayerkan
# Processing Record 34 of Set 9 | pisco
# Processing Record 35 of Set 9 | maceio
# Processing Record 36 of Set 9 | signagi
# City not found. Skipping...
# Processing Record 37 of Set 9 | jalalpur
# Processing Record 38 of Set 9 | hit
# Processing Record 39 of Set 9 | onega
# Processing Record 40 of Set 9 | morant bay
# Processing Record 41 of Set 9 | bani
# Processing Record 42 of Set 9 | alamor
# Processing Record 43 of Set 9 | darlowo
# Processing Record 44 of Set 9 | talah
# City not found. Skipping...
# Processing Record 45 of Set 9 | mehamn
# Processing Record 46 of Set 9 | togur
# Processing Record 47 of Set 9 | nioro
# Processing Record 48 of Set 9 | mbandaka
# Processing Record 49 of Set 9 | dudinka
# Processing Record 50 of Set 9 | howick
# Processing Record 1 of Set 10 | la chapelle-sur-erdre
# Processing Record 2 of Set 10 | gambela
# Processing Record 3 of Set 10 | clyde river
# Processing Record 4 of Set 10 | puerto narino
# Processing Record 5 of Set 10 | martinez
# Processing Record 6 of Set 10 | port hawkesbury
# Processing Record 7 of Set 10 | thompson
# Processing Record 8 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 9 of Set 10 | caceres
# Processing Record 10 of Set 10 | urucara
# Processing Record 11 of Set 10 | stornoway
# Processing Record 12 of Set 10 | forasti
# Processing Record 13 of Set 10 | karaton
# Processing Record 14 of Set 10 | machiques
# Processing Record 15 of Set 10 | qasigiannguit
# Processing Record 16 of Set 10 | tabuk
# Processing Record 17 of Set 10 | emba
# Processing Record 18 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 19 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 20 of Set 10 | caravelas
# Processing Record 21 of Set 10 | belene
# Processing Record 22 of Set 10 | oussouye
# Processing Record 23 of Set 10 | youghal
# Processing Record 24 of Set 10 | kemin
# Processing Record 25 of Set 10 | witu
# Processing Record 26 of Set 10 | bogorodskoye
# Processing Record 27 of Set 10 | brigantine
# Processing Record 28 of Set 10 | westport
# Processing Record 29 of Set 10 | chiojdu
# Processing Record 30 of Set 10 | carora
# Processing Record 31 of Set 10 | kroderen
# City not found. Skipping...
# Processing Record 32 of Set 10 | akureyri
# Processing Record 33 of Set 10 | doha
# Processing Record 34 of Set 10 | kentau
# Processing Record 35 of Set 10 | kidal
# Processing Record 36 of Set 10 | oshnaviyeh
# Processing Record 37 of Set 10 | marystown
# Processing Record 38 of Set 10 | copiapo
# Processing Record 39 of Set 10 | taltal
# Processing Record 40 of Set 10 | vangaindrano
# Processing Record 41 of Set 10 | jinka
# Processing Record 42 of Set 10 | skibbereen
# Processing Record 43 of Set 10 | kaduqli
# Processing Record 44 of Set 10 | imbituba
# Processing Record 45 of Set 10 | ambam
# Processing Record 46 of Set 10 | duz
# City not found. Skipping...
# Processing Record 47 of Set 10 | kannad
# Processing Record 48 of Set 10 | basqal
# Processing Record 49 of Set 10 | shieli
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | lauchhammer
# Processing Record 2 of Set 11 | caiaponia
# Processing Record 3 of Set 11 | jutai
# Processing Record 4 of Set 11 | castro
# Processing Record 5 of Set 11 | inhambane
# Processing Record 6 of Set 11 | belyy yar
# Processing Record 7 of Set 11 | ejea de los caballeros
# Processing Record 8 of Set 11 | kuraymah
# Processing Record 9 of Set 11 | buldana
# Processing Record 10 of Set 11 | kaniama
# Processing Record 11 of Set 11 | mogadishu
# Processing Record 12 of Set 11 | banda aceh
# Processing Record 13 of Set 11 | beira
# Processing Record 14 of Set 11 | port-gentil
# Processing Record 15 of Set 11 | hamilton
# Processing Record 16 of Set 11 | pangnirtung
# Processing Record 17 of Set 11 | kurtamysh
# Processing Record 18 of Set 11 | takoradi
# Processing Record 19 of Set 11 | rodnykove
# Processing Record 20 of Set 11 | manyana
# Processing Record 21 of Set 11 | binga
# Processing Record 22 of Set 11 | ust-ishim
# Processing Record 23 of Set 11 | teguldet
# Processing Record 24 of Set 11 | gweta
# Processing Record 25 of Set 11 | soyo
# Processing Record 26 of Set 11 | coruripe
# Processing Record 27 of Set 11 | richards bay
# Processing Record 28 of Set 11 | pritzwalk
# Processing Record 29 of Set 11 | masindi
# Processing Record 30 of Set 11 | mosjoen
# Processing Record 31 of Set 11 | porto velho
# Processing Record 32 of Set 11 | skelleftea
# Processing Record 33 of Set 11 | jadu
# Processing Record 34 of Set 11 | benghazi
# Processing Record 35 of Set 11 | volchikha
# Processing Record 36 of Set 11 | homa bay
# Processing Record 37 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 11 | katiola
# Processing Record 39 of Set 11 | harqalah
# Processing Record 40 of Set 11 | isla mujeres
# Processing Record 41 of Set 11 | shache
# Processing Record 42 of Set 11 | sault sainte marie
# Processing Record 43 of Set 11 | grand-lahou
# Processing Record 44 of Set 11 | antalaha
# Processing Record 45 of Set 11 | rio gallegos
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | robertsport
# Processing Record 48 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 11 | cap-aux-meules
# Processing Record 50 of Set 11 | rantoul
# Processing Record 1 of Set 12 | waddan
# Processing Record 2 of Set 12 | kavant
# City not found. Skipping...
# Processing Record 3 of Set 12 | kirovskiy
# Processing Record 4 of Set 12 | halvad
# Processing Record 5 of Set 12 | santa rosa
# Processing Record 6 of Set 12 | szczytno
# Processing Record 7 of Set 12 | lonevag
# Processing Record 8 of Set 12 | boden
# Processing Record 9 of Set 12 | nova serrana
# Processing Record 10 of Set 12 | bongandanga
# Processing Record 11 of Set 12 | anloga
# Processing Record 12 of Set 12 | paita
# Processing Record 13 of Set 12 | kiknur
# Processing Record 14 of Set 12 | placido de castro
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | sisimiut
# Processing Record 17 of Set 12 | lodja
# Processing Record 18 of Set 12 | matara
# Processing Record 19 of Set 12 | lima
# Processing Record 20 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 12 | octeville
# Processing Record 22 of Set 12 | chany
# Processing Record 23 of Set 12 | mormugao
# Processing Record 24 of Set 12 | mbacke
# City not found. Skipping...
# Processing Record 25 of Set 12 | oxford
# Processing Record 26 of Set 12 | ciudad bolivar
# Processing Record 27 of Set 12 | nigde
# Processing Record 28 of Set 12 | pajan
# Processing Record 29 of Set 12 | pimenta bueno
# Processing Record 30 of Set 12 | bardiyah
# Processing Record 31 of Set 12 | beri
# Processing Record 32 of Set 12 | aqtobe
# Processing Record 33 of Set 12 | sao raimundo nonato
# Processing Record 34 of Set 12 | puerto leguizamo
# Processing Record 35 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | gopalganj
# Processing Record 38 of Set 12 | constitucion
# Processing Record 39 of Set 12 | baherden
# Processing Record 40 of Set 12 | gualaquiza
# Processing Record 41 of Set 12 | amos
# Processing Record 42 of Set 12 | luanda
# Processing Record 43 of Set 12 | larsnes
# Processing Record 44 of Set 12 | danilovka
# Processing Record 45 of Set 12 | betioky
# Processing Record 46 of Set 12 | kulynychi
# Processing Record 47 of Set 12 | theunissen
# Processing Record 48 of Set 12 | dabat
# Processing Record 49 of Set 12 | santiago del estero
# Processing Record 50 of Set 12 | puerto lempira
# Processing Record 1 of Set 13 | beloha
# Processing Record 2 of Set 13 | soavinandriana
# Processing Record 3 of Set 13 | abonnema
# Processing Record 4 of Set 13 | moen
# Processing Record 5 of Set 13 | maldonado
# Processing Record 6 of Set 13 | przhevalskoye
# Processing Record 7 of Set 13 | skegness
# Processing Record 8 of Set 13 | elat
# Processing Record 9 of Set 13 | mercedes
# Processing Record 10 of Set 13 | puerto baquerizo moreno
# Processing Record 11 of Set 13 | roald
# Processing Record 12 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 13 of Set 13 | meulaboh
# Processing Record 14 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 13 | ust-kulom
# Processing Record 16 of Set 13 | abha
# Processing Record 17 of Set 13 | blagoyevo
# Processing Record 18 of Set 13 | puerto colombia
# Processing Record 19 of Set 13 | zholymbet
# Processing Record 20 of Set 13 | wajir
# Processing Record 21 of Set 13 | mazabuka
# Processing Record 22 of Set 13 | bubaque
# Processing Record 23 of Set 13 | morgantown
# Processing Record 24 of Set 13 | rocha
# Processing Record 25 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 13 | angoche
# Processing Record 27 of Set 13 | cefalu
# Processing Record 28 of Set 13 | maputo
# Processing Record 29 of Set 13 | lvov
# Processing Record 30 of Set 13 | brae
# Processing Record 31 of Set 13 | nefteyugansk
# Processing Record 32 of Set 13 | guider
# Processing Record 33 of Set 13 | camocim
# Processing Record 34 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 13 | iskilip
# Processing Record 38 of Set 13 | maarianhamina
# Processing Record 39 of Set 13 | aksu
# Processing Record 40 of Set 13 | kambove
# Processing Record 41 of Set 13 | sile
# Processing Record 42 of Set 13 | rockland
# Processing Record 43 of Set 13 | iskateley
# Processing Record 44 of Set 13 | goderich
# Processing Record 45 of Set 13 | aswan
# Processing Record 46 of Set 13 | monrovia
# Processing Record 47 of Set 13 | bridgwater
# Processing Record 48 of Set 13 | nueva loja
# Processing Record 49 of Set 13 | patti
# Processing Record 50 of Set 13 | hobyo
# Processing Record 1 of Set 14 | ottobrunn
# Processing Record 2 of Set 14 | gataia
# Processing Record 3 of Set 14 | alta
# Processing Record 4 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 14 | esna
# Processing Record 6 of Set 14 | manali
# Processing Record 7 of Set 14 | galle
# Processing Record 8 of Set 14 | montepuez
# Processing Record 9 of Set 14 | lar
# Processing Record 10 of Set 14 | usinsk
# Processing Record 11 of Set 14 | sidi bu zayd
# City not found. Skipping...
# Processing Record 12 of Set 14 | pombia
# Processing Record 13 of Set 14 | maraa
# Processing Record 14 of Set 14 | ilebo
# Processing Record 15 of Set 14 | malanje
# Processing Record 16 of Set 14 | ambilobe
# Processing Record 17 of Set 14 | mitu
# Processing Record 18 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 19 of Set 14 | tshane
# Processing Record 20 of Set 14 | perigueux
# Processing Record 21 of Set 14 | sabana de torres
# Processing Record 22 of Set 14 | geraldton
# Processing Record 23 of Set 14 | dera ghazi khan
# Processing Record 24 of Set 14 | taywarah
# Processing Record 25 of Set 14 | napasar
# Processing Record 26 of Set 14 | panama city
# Processing Record 27 of Set 14 | grootfontein
# Processing Record 28 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 14 | ankazoabo
# Processing Record 30 of Set 14 | berbera
# Processing Record 31 of Set 14 | santa marta
# Processing Record 32 of Set 14 | kijini
# Processing Record 33 of Set 14 | odweyne
# Processing Record 34 of Set 14 | karanpura
# Processing Record 35 of Set 14 | sarai naurang
# Processing Record 36 of Set 14 | challapata
# Processing Record 37 of Set 14 | north myrtle beach
# Processing Record 38 of Set 14 | campoverde
# Processing Record 39 of Set 14 | carnarvon
# Processing Record 40 of Set 14 | rabak
# Processing Record 41 of Set 14 | grindavik
# Processing Record 42 of Set 14 | sinnar
# Processing Record 43 of Set 14 | plouzane
# Processing Record 44 of Set 14 | kalmunai
# Processing Record 45 of Set 14 | camabatela
# Processing Record 46 of Set 14 | sept-iles
# Processing Record 47 of Set 14 | matthews
# Processing Record 48 of Set 14 | paros
# Processing Record 49 of Set 14 | oum hadjer
# Processing Record 50 of Set 14 | alakurtti
# Processing Record 1 of Set 15 | itamaraju
# Processing Record 2 of Set 15 | nikel
# Processing Record 3 of Set 15 | sembe
# Processing Record 4 of Set 15 | andenes
# Processing Record 5 of Set 15 | acarau
# Processing Record 6 of Set 15 | mao
# Processing Record 7 of Set 15 | rio branco
# Processing Record 8 of Set 15 | yenagoa
# Processing Record 9 of Set 15 | mananjary
# Processing Record 10 of Set 15 | mecca
# Processing Record 11 of Set 15 | dhidhdhoo
# Processing Record 12 of Set 15 | awbari
# Processing Record 13 of Set 15 | koygorodok
# Processing Record 14 of Set 15 | were ilu
# Processing Record 15 of Set 15 | zemio
# Processing Record 16 of Set 15 | aguimes
# Processing Record 17 of Set 15 | bolzano
# Processing Record 18 of Set 15 | evansville
# Processing Record 19 of Set 15 | el cobre
# Processing Record 20 of Set 15 | plettenberg bay
# Processing Record 21 of Set 15 | prainha
# Processing Record 22 of Set 15 | gwembe
# Processing Record 23 of Set 15 | obera
# Processing Record 24 of Set 15 | umea
# Processing Record 25 of Set 15 | rauma
# Processing Record 26 of Set 15 | harrisburg
# Processing Record 27 of Set 15 | cruz alta
# Processing Record 28 of Set 15 | dmitriyevka
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | libertador general san martin
# Processing Record 31 of Set 15 | semme
# Processing Record 32 of Set 15 | gorshechnoye
# Processing Record 33 of Set 15 | disna
# Processing Record 34 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 15 | chik
# Processing Record 36 of Set 15 | mantua
# Processing Record 37 of Set 15 | alfenas
# Processing Record 38 of Set 15 | siuna
# Processing Record 39 of Set 15 | warmbad
# Processing Record 40 of Set 15 | lokken verk
# City not found. Skipping...
# Processing Record 41 of Set 15 | prilep
# Processing Record 42 of Set 15 | taggia
# Processing Record 43 of Set 15 | varhaug
# Processing Record 44 of Set 15 | pyaozerskiy
# Processing Record 45 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 15 | pachino
# Processing Record 47 of Set 15 | panaba
# Processing Record 48 of Set 15 | krasnogvardeyskiy
# Processing Record 49 of Set 15 | gurupi
# Processing Record 50 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 16 | veraval
# Processing Record 2 of Set 16 | banposh
# Processing Record 3 of Set 16 | state college
# Processing Record 4 of Set 16 | kabalo
# Processing Record 5 of Set 16 | keti bandar
# Processing Record 6 of Set 16 | nahavand
# Processing Record 7 of Set 16 | decatur
# Processing Record 8 of Set 16 | lubaczow
# Processing Record 9 of Set 16 | znamenka
# Processing Record 10 of Set 16 | japura
# Processing Record 11 of Set 16 | korem
# Processing Record 12 of Set 16 | yendi
# Processing Record 13 of Set 16 | havoysund
# Processing Record 14 of Set 16 | lennoxtown
# Processing Record 15 of Set 16 | carutapera
# Processing Record 16 of Set 16 | tayga
# Processing Record 17 of Set 16 | kharp
# Processing Record 18 of Set 16 | valparaiso
# Processing Record 19 of Set 16 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
city_data_df.head()
# Out:
#                  City Country      Lat      Lng  Max Temp  Humidity  \
# 0               Florø      NO  61.5996   5.0328     48.16        87
# 1              Torbay      CA  47.6666 -52.7314     63.27        83
# 2             Methóni      GR  36.8197  21.7049     90.21        52
# 3           Salamiyah      SY  35.0113  37.0532     77.99        47
# 4  San Rafael del Sur      NI  11.8485 -86.4384     77.94        85
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.00     overcast clouds
# 1           2        5.99           clear sky
# 2           0        6.89           clear sky
# 3           0        5.70           clear sky
# 4         100        9.66     overcast clouds
